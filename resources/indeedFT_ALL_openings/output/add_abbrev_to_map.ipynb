# %%
import pandas as pd
import csv

# %%
# load in CSV
all_openings_df = pd.read_csv("new.csv")
all_openings_df.head()
# Out:
#         state openings
# 0     Alabama   33,474
# 1      Alaska    5,440
# 2     Arizona   57,242
# 3    Arkansas   18,036
# 4  California  310,250

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
all_openings_df['st'] = all_openings_df['state'].map(us_state_abbrev)

# %%
all_openings_df
# Out:
#                    state openings   st
# 0                Alabama   33,474   AL
# 1                 Alaska    5,440   AK
# 2                Arizona   57,242   AZ
# 3               Arkansas   18,036   AR
# 4             California  310,250   CA
# 5               Colorado   62,027   CO
# 6            Connecticut   28,020   CT
# 7               Delaware    7,971   DE
# 8   District of Columbia   72,182   DC
# 9                Florida  176,265   FL
# 10               Georgia   86,304   GA
# 11                Hawaii   11,667   HI
# 12                 Idaho   10,846   ID
# 13              Illinois  112,230   IL
# 14               Indiana   60,099   IN
# 15                  Iowa   28,679   IA
# 16                Kansas   26,161   KS
# 17              Kentucky   34,598   KY
# 18             Louisiana   30,098   LA
# 19                 Maine   10,848   ME
# 20              Maryland   57,202   MD
# 21         Massachusetts   82,313   MA
# 22              Michigan   74,862   MI
# ...

# %%
all_openings_df.to_csv("all_openings_to_plotly.csv")
